# %%
#Topic :List

# %%
#1. Create a list of 5 random numbers and print the list.
a=[1,3,5,7,9]
a
# Out:
# [1, 3, 5, 7, 9]

# %%
#2. Insert 3 new values to the list and print the updated list.
a.extend([2,4,6])
a
# Out:
# [1, 3, 5, 7, 9, 2, 4, 6]

# %%
#3. Try to use a for loop to print each element in the list.
for i in a:
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9
# 2
# 4
# 6

# %%
#Topic: Dictionary

# %%
#1. Create a dictionary with keys 'name', 'age', and 'address' and values 'John', 25, and 'New York' respectively.
b=dict({"Name":"John","Age":25,"Address":"New York"})
print(b)
# Out:
# {'Name': 'John', 'Age': 25, 'Address': 'New York'}

# %%
#2. Add a new key-value pair to the dictionary created in Question 1 with key 'phone' and value '1234567890'.
b["Phone"]=1234567890
print(b)
# Out:
# {'Name': 'John', 'Age': 25, 'Address': 'New York', 'Phone': 1234567890}

# %%
#Topic: Set

# %%
#1.Create a set with values 1, 2, 3, 4, and 5.
c={1,2,3,4,5}
c
# Out:
# {1, 2, 3, 4, 5}

# %%
#2. Add the value 6 to the set created in Question 1.
c.add(6)
c
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
#3. Remove the value 3 from the set created in Question 1.
c.remove(3)
c
# Out:
# {1, 2, 4, 5, 6}

# %%
#Topic:Tuple

# %%
#1. Create a tuple with values 1, 2, 3, and 4
d=(1,2,3,4)
d
# Out:
# (1, 2, 3, 4)

# %%
#2. Print the length of the tuple created in Question 1.
print(len(d))
# Out:
# 4
